# %%
import pandas

# %%
import numpy
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Load the datasets
df_smoking_rates = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\table_e90dbf0b-10da-42c9-9938-f13a24c38101.csv')
df_cigarette_use_2018 = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\Current Cigarette Use Among Adults (Behavior Risk Factor Surveillance System) 2018.csv')


print("Smoking Rates Columns:", df_smoking_rates.columns)
print("Cigarette Use 2018 Columns:", df_cigarette_use_2018.columns)
# Out:
# Smoking Rates Columns: Index(['year', 'Heavy smokers', 'Moderate smokers', 'Light smokers'], dtype='object')
# Cigarette Use 2018 Columns: Index(['Location', 'Data_Value', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size'],
#       dtype='object')

# %%
import pandas as pd


df_smoking_rates = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\table_e90dbf0b-10da-42c9-9938-f13a24c38101.csv')
df_cigarette_use_2018 = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\Current Cigarette Use Among Adults (Behavior Risk Factor Surveillance System) 2018.csv')


print("Columns in df_smoking_rates:", df_smoking_rates.columns)
print("Columns in df_cigarette_use_2018:", df_cigarette_use_2018.columns)
# Out:
# Columns in df_smoking_rates: Index(['year', 'Heavy smokers', 'Moderate smokers', 'Light smokers'], dtype='object')
# Columns in df_cigarette_use_2018: Index(['Location', 'Data_Value', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size'],
#       dtype='object')

# %%
import pandas as pd


df_smoking_rates = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\table_e90dbf0b-10da-42c9-9938-f13a24c38101.csv')
df_death_causes = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\table_1fdb7992-7c9a-4fb3-9504-f8cce7e0154d.csv')
df_smoking_health = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\table_ebec359a-f771-4180-8957-42d8334d72e9.csv')
df_cigarette_use_2018 = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\Current Cigarette Use Among Adults (Behavior Risk Factor Surveillance System) 2018.csv')



print("Smoking Rates Columns:", df_smoking_rates.columns)
print("Death Causes Columns:", df_death_causes.columns)
print("Smoking Health Columns:", df_smoking_health.columns)
print("Cigarette Use 2018 Columns:", df_cigarette_use_2018.columns)
# Out:
# Smoking Rates Columns: Index(['year', 'Heavy smokers', 'Moderate smokers', 'Light smokers'], dtype='object')
# Death Causes Columns: Index(['category', 'Non-natural cause', 'Other natural cause',
#        'Respiratory disease', 'Cardiovascular disease', 'Other form of cancer',
#        'Lung cancer'],
#       dtype='object')
# Smoking Health Columns: Index(['year', 'Heavy smoker', 'Moderate smoker', 'Light smoker',
#        'Non-smoker'],
#       dtype='object')
# Cigarette Use 2018 Columns: Index(['Location', 'Data_Value', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


heatmap_data = df_smoking_rates.set_index('year')
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu')
plt.title('Smoking Rates Over Time')
plt.xlabel('Smoker Type')
plt.ylabel('Year')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df_death_causes = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\table_1fdb7992-7c9a-4fb3-9504-f8cce7e0154d.csv')


death_causes_sum = df_death_causes[['Non-natural cause', 'Other natural cause', 'Respiratory disease', 'Cardiovascular disease', 'Other form of cancer', 'Lung cancer']].sum()
death_causes_sum.plot(kind='bar')
plt.title('Sum of Causes of Death from Dataset')
plt.ylabel('Count')
plt.xlabel('Cause of Death')
plt.show()

# %%
sns.clustermap(df_smoking_rates.drop('year', axis=1), standard_scale=1)
plt.title('Cluster Map of Smoking Rates')
plt.show()

# %%
pd.plotting.scatter_matrix(df_smoking_rates.drop('year', axis=1), alpha=0.2, figsize=(10, 10))
plt.title('Scatter Plot Matrix of Smoking Data')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_sorted = df_cigarette_use_2018.sort_values(by='Data_Value', ascending=False)

plt.figure(figsize=(14, 7))
sns.barplot(x='Location', y='Data_Value', data=df_sorted, palette='viridis') 

plt.xticks(rotation=90)
plt.title('Distribution of Smoking Rates by State (2018)')
plt.xlabel('State')
plt.ylabel('Smoking Rate (%)')


for index, value in enumerate(df_sorted['Data_Value']):
    plt.text(index, value, f'{value:.1f}', ha='center', va='bottom', fontsize=8, rotation=90)

plt.tight_layout() 

plt.show()
# Out:
# C:\Users\priyansh singh\AppData\Local\Temp\ipykernel_20740\2608047745.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Location', y='Data_Value', data=df_sorted, palette='viridis')  # Using a visually appealing color palette
# posx and posy should be finite values
# posx and posy should be finite values

# %%
df_alzheimers_data['Data_Value'].hist(by=df_alzheimers_data['YearStart'])
plt.title('Alzheimer\'s Disease Data Distribution by Year')
plt.xlabel('Data Value')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\Current Cigarette Use Among Adults (Behavior Risk Factor Surveillance System) 2018.csv')

# Define thresholds for categorization (adjust these based on your data analysis)
low_threshold = 15
moderate_threshold_low = 15
moderate_threshold_high = 30
high_threshold = 30

# Define conditions and categories for smoker categorization based on confidence limits and Data_Value
conditions = [
    (df['Low_Confidence_Limit'] > high_threshold),  # High smokers: lower bound is above high threshold
    (df['Data_Value'] > moderate_threshold_low) & (df['Data_Value'] <= moderate_threshold_high),  # Moderate smokers: data value within moderate range
    (df['High_Confidence_Limit'] < low_threshold)  # Low smokers: upper bound is below low threshold
]
categories = ['High', 'Moderate', 'Low']
df['Smoker_Category'] = np.select(conditions, categories, default='Uncategorized')

# Display categorized data
print(df[['Location', 'Data_Value', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'Smoker_Category']].head())

# Group by location and category to summarize data
grouped_df = df.groupby(['Location', 'Smoker_Category']).size().unstack(fill_value=0)
print(grouped_df)

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))
grouped_df.plot(kind='bar', stacked=True, ax=ax)
plt.title('Number of Smokers by Category and Location')
plt.xlabel('Location')
plt.ylabel('Number of Smokers')
plt.xticks(rotation=45)
plt.legend(title='Smoker Category')
plt.tight_layout()
plt.show()
# Out:
#      Location  Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# 0     Alabama        19.2                  17.9                   20.5
# 1      Alaska        19.1                  16.9                   21.3
# 2     Arizona        14.0                  12.7                   15.3
# 3    Arkansas        22.7                  20.9                   24.5
# 4  California        11.2                  10.4                   12.0
#
#   Smoker_Category
# 0        Moderate
# 1        Moderate
# 2   Uncategorized
# 3        Moderate
# 4             Low
# Smoker_Category       Low  Moderate  Uncategorized
# Location
# Alabama                 0         1              0
# Alaska                  0         1              0
# Arizona                 0         0              1
# Arkansas                0         1              0
# California              1         0              0
# Colorado                0         0              1
# Connecticut             1         0              0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r'C:\Users\priyansh singh\Documents\GitHub\age_detection_project\Current Cigarette Use Among Adults (Behavior Risk Factor Surveillance System) 2018.csv')

# Print column names to verify the correct columns
print("Columns in the dataset:", df.columns)

# Define conditions and categories for smoker categorization based on an example 'Data_Value'
conditions = [
    (df['Data_Value'] <= 20),  # Assumed threshold for 'Low'
    (df['Data_Value'] > 20) & (df['Data_Value'] <= 40),  # Assumed threshold for 'Moderate'
    (df['Data_Value'] > 40)  # Assumed threshold for 'High'
]
categories = ['Low', 'Moderate', 'High']
df['Category'] = np.select(conditions, categories, default='Unknown')

# Print to verify new column and show the first few rows
print(df[['Data_Value', 'Category']].head())

# Group by location and category to summarize data
grouped_df = df.groupby(['Location', 'Category']).size().unstack(fill_value=0)
print(grouped_df)

# Creating plot (if the correct column name is known)
fig, ax = plt.subplots(figsize=(10, 6))

# Insert the correct column name in place of 'COLUMN_NAME_FOR_PLOTTING'
# Example: Assume 'Data_Value' is what you want to plot
if 'Data_Value' in df.columns and df['Data_Value'].var() > 0:
    sns.kdeplot(df['Data_Value'], label='Data Value')
else:
    print("Skipping KDE plot due to zero variance or incorrect column.")

plt.legend(title='Data Value')
plt.title('Density Plot for Data Value')
plt.xlabel('Data Value')
plt.ylabel('Density')
plt.show()

# Display summary by location and category in a grouped bar chart
grouped_df.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Number of Smokers by Category and Location')
plt.xlabel('Location')
plt.ylabel('Number of Smokers')
plt.xticks(rotation=45)
plt.legend(title='Smoker Category')
plt.tight_layout()
plt.show()
# Out:
# Columns in the dataset: Index(['Location', 'Data_Value', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size'],
#       dtype='object')
#    Data_Value  Category
# 0        19.2       Low
# 1        19.1       Low
# 2        14.0       Low
# 3        22.7  Moderate
# 4        11.2       Low
# Category              Low  Moderate
# Location
# Alabama                 1         0
# Alaska                  1         0
# Arizona                 1         0
# Arkansas                0         1
# California              1         0
# Colorado                1         0
# Connecticut             1         0
# Delaware                1         0
# District of Columbia    1         0
# Florida                 1         0
# Georgia                 1         0
# Guam                    0         1
# Hawaii                  1         0
# Idaho                   1         0
# Illinois                1         0
# Indiana                 0         1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


df_smoking_rates = pd.DataFrame({
    'year': [2015, 2016, 2017, 2018, 2019],
    'Heavy smokers': [200, 190, 180, 170, 160],
    'Moderate smokers': [300, 310, 320, 330, 340],
    'Light smokers': [500, 490, 480, 470, 460]
})


df_health_outcomes = pd.DataFrame({
    'year': [2015, 2016, 2017, 2018, 2019],
    'Deaths from heavy smoking': [50, 48, 46, 44, 42],
    'Deaths from moderate smoking': [30, 31, 32, 33, 34],
    'Deaths from light smoking': [10, 9, 8, 7, 6]
})


merged_data = pd.merge(df_smoking_rates, df_health_outcomes, on='year')


fig, ax1 = plt.subplots(figsize=(10, 6))


ax1.bar(merged_data['year'] - 0.2, merged_data['Heavy smokers'], width=0.2, color='darkred', label='Heavy Smokers')
ax1.bar(merged_data['year'], merged_data['Moderate smokers'], width=0.2, color='orange', label='Moderate Smokers')
ax1.bar(merged_data['year'] + 0.2, merged_data['Light smokers'], width=0.2, color='yellow', label='Light Smokers')
ax1.set_xlabel('Year')
ax1.set_ylabel('Number of Smokers')
ax1.legend(loc='upper left')


ax2 = ax1.twinx()
ax2.plot(merged_data['year'], merged_data['Deaths from heavy smoking'], 'r-o', label='Deaths - Heavy Smoking')
ax2.plot(merged_data['year'], merged_data['Deaths from moderate smoking'], 'b-o', label='Deaths - Moderate Smoking')
ax2.plot(merged_data['year'], merged_data['Deaths from light smoking'], 'g-o', label='Deaths - Light Smoking')
ax2.set_ylabel('Number of Deaths')
ax2.legend(loc='upper right')

plt.title('Smoking Habits vs. Smoking Related Deaths Over the Years')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


data_smokers = pd.DataFrame({
    'category': ['Low', 'Moderate', 'High'],
    'smokers': [500, 300, 200]  
})

data_deaths = pd.DataFrame({
    'category': ['Low', 'Moderate', 'High'],
    'deaths': [50, 90, 160]  
})


merged_data = pd.merge(data_smokers, data_deaths, on='category')


fig, ax1 = plt.subplots()


colors = ['lightblue', 'orange', 'red']
ax1.bar(merged_data['category'], merged_data['smokers'], color=colors, alpha=0.6, label='Number of Smokers (x1000)')
ax1.set_xlabel('Smoking Category')
ax1.set_ylabel('Number of Smokers (x1000)')
ax1.set_title('Comparison of Smoking Categories and Deaths')


ax2 = ax1.twinx()
ax2.plot(merged_data['category'], merged_data['deaths'], 'k-o', label='Deaths (x100)')
ax2.set_ylabel('Deaths (x100)')


lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %%
print(df_smoking_health.columns)
# Out:
# Index([' ', 'Heavy smoker', 'Moderate smoker', 'Light smoker', 'Non-smoker'], dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


conditions = [
    (df_smoking_rates['Heavy smokers'] > 20),  
    (df_smoking_rates['Heavy smokers'] > 15) & (df_smoking_rates['Heavy smokers'] <= 20),  # Heavy Smoker
    (df_smoking_rates['Moderate smokers'] > 5) & (df_smoking_rates['Moderate smokers'] <= 15),  # Moderate Smoker
    (df_smoking_rates['Light smokers'] <= 5)  # Light Smoker
]
choices = ['High smoker', 'Heavy smoker', 'Moderate smoker', 'Light smoker']
df_smoking_rates['category'] = np.select(conditions, choices, default='Non-smoker')


average_smoking_data = df_smoking_rates.groupby('category').mean().reset_index()


merged_data = pd.merge(average_smoking_data, df_death_causes, on='category', how='inner')


grouped_data = merged_data.groupby('category').mean().reset_index()


plt.figure(figsize=(14, 7))
sns.barplot(x='category', y='Lung cancer', data=grouped_data, label='Lung Cancer', color='red')
sns.barplot(x='category', y='Cardiovascular disease', data=grouped_data, label='Cardiovascular Disease', color='blue')
plt.title('Health Outcomes by Smoking Category')
plt.xlabel('Smoking Category')
plt.ylabel('Average Cases')
plt.legend()
plt.show()
